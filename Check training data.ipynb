# %%
from segmentation_training import *
# Out:
# Using TensorFlow backend.

# %%
train_gen = NumpyDataGenerator('./training_data/train/', 6, shuffle=True)
# Out:
# Data generator initialized on 533 samples

# %%
X, y = train_gen.__getitem__(0)

# %%
plt.imshow(X[0])

# %%
plt.imshow(y[0])

# %%
rand = np.random.randint(6)
plt.imshow(((X[rand] + y[rand]) * 255).astype('int'))

# %%
# Out:
# 1
